# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2*np.pi,np.pi*2,1000)
y = np.cos(x)
y2 = np.sin(x)
plt.figure(figsize=(10,6))
plt.plot(x,y,label='y=cos(x)')
plt.plot(x,y2,label='y=sin(x)')

plt.xticks([i for i in np.arange(-2*np.pi,2*np.pi+1,np.pi/2)],
           [f'{round(i/np.pi,1)}'+'$\pi$' for i in np.arange(-2*np.pi,2*np.pi+1,np.pi/2)],
           )
ax = plt.gca()
plt.legend(frameon=False,loc='best')
ax.spines['left'].set_position(('data',0)) 
ax.spines['bottom'].set_position(('data',0)) 
ax.spines['top'].set_color(None) 
ax.spines['right'].set_color(None)

# %%
ls = [f'{round(i/np.pi)}'+'$\pi$' for i in np.arange(-6*np.pi,6*np.pi+1,np.pi/2)]
ls
# Out:
# ['-6$\\pi$',
#  '-5$\\pi$',
#  '-5$\\pi$',
#  '-4$\\pi$',
#  '-4$\\pi$',
#  '-3$\\pi$',
#  '-3$\\pi$',
#  '-2$\\pi$',
#  '-2$\\pi$',
#  '-1$\\pi$',
#  '-1$\\pi$',
#  '0$\\pi$',
#  '0$\\pi$',
#  '1$\\pi$',
#  '1$\\pi$',
#  '2$\\pi$',
#  '2$\\pi$',
#  '3$\\pi$',
#  '3$\\pi$',
#  '4$\\pi$',
#  '4$\\pi$',
#  '5$\\pi$',
#  '5$\\pi$',
#  '6$\\pi$',
#  '6$\\pi$']

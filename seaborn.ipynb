# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sns.set_theme(style='white')
f = sns.load_dataset('iris')
f.head()
plt.plot(f['sepal_length'], f['sepal_width'], marker='o', color='r',ls='')
sns.plot(data=f,x='sepal_length',y='sepal_width')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       3 f.head()
#       4 plt.plot(f['sepal_length'], f['sepal_width'], marker='o', color='r',ls='')
# ----> 5 sns.plot(data=f,x='sepal_length',y='sepal_width')
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
import seaborn as sns
sns.set_theme(style="white")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>
